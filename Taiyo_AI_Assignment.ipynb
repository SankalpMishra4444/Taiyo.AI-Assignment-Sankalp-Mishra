# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://developer.taiyo.ai/api-doc/TimeSeries/'
req = requests.get(url)
print(req) #To verify output
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content, 'html.parser')
#print(soup) #To verify output (VERY LONG)

# %%
tabela = soup.find(name='table')
#print(tabela) #To verify output (VERY LONG)

# %%
print(tabela)
# Out:
# <table>
# <thead>
# <tr>
# <th>Primary Fields</th>
# <th>Description</th>
# <th>Notes</th>
# <th>Additional Comments</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Identifier</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>aug_id</td>
# <td>ID generated for unique identification</td>
# <td>This resembles {source}_{original_id}</td>
# <td></td>
# </tr>
# <tr>
# <td>original_id</td>
# <td>ID originally provided by the data source</td>
# <td></td>
# <td>If this ID is not present it is to be generated from the asset name or title</td>
# </tr>
# <tr>
# <td>sample_frequency</td>
# <td>sample frequency of the time_series</td>
# <td>Valid Values or Daily, Weekly, Monthly, Quaterly</td>
# <td></td>
# </tr>
# <tr>
# <td>Basic Specs</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>name</td>
# <td>Name or Title of the time series</td>
# <td></td>
# <td></td>
# </tr>
# <tr>
# <td>description</td>
# <td>Any descriptive information present about the timeseries</td>
# ...

# %%
df = pd.concat(pd.read_html('https://developer.taiyo.ai/api-doc/TimeSeries/'),axis=1)

# %%
df.head(5)
# Out:
#      Primary Fields                                Description  \
# 0        Identifier                                        NaN
# 1            aug_id     ID generated for unique identification
# 2       original_id  ID originally provided by the data source
# 3  sample_frequency        sample frequency of the time_series
# 4       Basic Specs                                        NaN
#
#                                               Notes  \
# 0                                               NaN
# 1             This resembles {source}_{original_id}
# 2                                               NaN
# 3  Valid Values or Daily, Weekly, Monthly, Quaterly
# 4                                               NaN
#
#                                  Additional Comments
# 0                                                NaN
# 1                                                NaN
# 2  If this ID is not present it is to be generate...
# 3                                                NaN
# ...

# %%
# saving the dataframe
df.to_csv('file1.csv')
